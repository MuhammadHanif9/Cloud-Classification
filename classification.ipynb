# %%
from ultralytics import YOLO

# %%
# Run inference on an image with YOLOv8n
# !yolo predict model=my_classification_model.pt source=testing.jpeg
# Out:
# Ultralytics YOLOv8.1.8 🚀 Python-3.11.5 torch-2.1.2+cpu CPU (Intel Core(TM) i3-1005G1 1.20GHz)
# YOLOv8n-cls summary (fused): 73 layers, 1441285 parameters, 0 gradients, 3.3 GFLOPs
#
# image 1/1 c:\Users\Muhammad Hanif PC\Desktop\project\ultralytics\testing.jpeg: 224x224 Cirroculumulus 0.38, Cumulus 0.30, Cirrus 0.23, Cumulonimbus 0.08, Altostratus 0.01, 52.0ms
# Speed: 6.3ms preprocess, 52.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to c:\Users\Muhammad Hanif PC\Desktop\project\ultralytics\runs\classify\predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import matplotlib.pyplot as plt

# %%
l=plt.imread("C:\\Users\\Muhammad Hanif PC\\Desktop\\project\\ultralytics\\runs\\classify\\predict2\\classify.jpeg")

# %%
plt.imshow(l)
